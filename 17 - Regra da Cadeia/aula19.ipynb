# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ------------------------

# %% [markdown]
# # Questão 01

# %%
X = np.linspace(-5, 5, 10)
X
# Out:
# array([-5.        , -3.88888889, -2.77777778, -1.66666667, -0.55555556,
#         0.55555556,  1.66666667,  2.77777778,  3.88888889,  5.        ])

# %%
Ya = [2 for i in range(10)]
Ya
# Out:
# [2, 2, 2, 2, 2, 2, 2, 2, 2, 2]

# %%
Yb = X
Yb
# Out:
# array([-5.        , -3.88888889, -2.77777778, -1.66666667, -0.55555556,
#         0.55555556,  1.66666667,  2.77777778,  3.88888889,  5.        ])

# %%
Yc = 2*X
Yc
# Out:
# array([-10.        ,  -7.77777778,  -5.55555556,  -3.33333333,
#         -1.11111111,   1.11111111,   3.33333333,   5.55555556,
#          7.77777778,  10.        ])

# %%
Yd = 3*X
Yd
# Out:
# array([-15.        , -11.66666667,  -8.33333333,  -5.        ,
#         -1.66666667,   1.66666667,   5.        ,   8.33333333,
#         11.66666667,  15.        ])

# %%
Ye = X/2
Ye
# Out:
# array([-2.5       , -1.94444444, -1.38888889, -0.83333333, -0.27777778,
#         0.27777778,  0.83333333,  1.38888889,  1.94444444,  2.5       ])

# %%
Yf = 2*X - 5
Yf
# Out:
# array([-15.        , -12.77777778, -10.55555556,  -8.33333333,
#         -6.11111111,  -3.88888889,  -1.66666667,   0.55555556,
#          2.77777778,   5.        ])

# %%
Yg = 2*(X-2) - 5
Yg
# Out:
# array([-19.        , -16.77777778, -14.55555556, -12.33333333,
#        -10.11111111,  -7.88888889,  -5.66666667,  -3.44444444,
#         -1.22222222,   1.        ])

# %%
fig, ax = plt.subplots()

ax.plot(X, Ya)

ax.grid(True)

fig.show()
# Out:
# /tmp/ipykernel_9225/1424806307.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots()

ax.plot(X, Yb)
ax.plot(X, Yc)
ax.plot(X, Yd)
ax.plot(X, Ye)

ax.grid(True)

fig.show()
# Out:
# /tmp/ipykernel_9225/889045898.py:10: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots()

ax.plot(X, Yc)
ax.plot(X, Yf)
ax.plot(X, Yg)

ax.grid(True)

fig.show()
# Out:
# /tmp/ipykernel_9225/723254080.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ----------------------------

# %% [markdown]
# # Questão 02

# %%
X = np.linspace(-5, 5, 10)
X
# Out:
# array([-5.        , -3.88888889, -2.77777778, -1.66666667, -0.55555556,
#         0.55555556,  1.66666667,  2.77777778,  3.88888889,  5.        ])

# %%
Ya = X + 3
Ya
# Out:
# array([-2.        , -0.88888889,  0.22222222,  1.33333333,  2.44444444,
#         3.55555556,  4.66666667,  5.77777778,  6.88888889,  8.        ])

# %%
Yb = (4-2*X)/3
Yb
# Out:
# array([ 4.66666667,  3.92592593,  3.18518519,  2.44444444,  1.7037037 ,
#         0.96296296,  0.22222222, -0.51851852, -1.25925926, -2.        ])

# %%
fig, ax = plt.subplots()

ax.plot(X, Ya)
ax.plot(X, Yb)

ax.grid(True)

fig.show()
# Out:
# /tmp/ipykernel_9225/3818759264.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# -----------------------

# %% [markdown]
# # Questão 04

# %%
X = np.linspace(0, 5, 10)
X
# Out:
# array([0.        , 0.55555556, 1.11111111, 1.66666667, 2.22222222,
#        2.77777778, 3.33333333, 3.88888889, 4.44444444, 5.        ])

# %%
Y1 = (15 - 3*X)/6
Y1
# Out:
# array([2.5       , 2.22222222, 1.94444444, 1.66666667, 1.38888889,
#        1.11111111, 0.83333333, 0.55555556, 0.27777778, 0.        ])

# %%
Y2 = 4 - 2*X
Y2
# Out:
# array([ 4.        ,  2.88888889,  1.77777778,  0.66666667, -0.44444444,
#        -1.55555556, -2.66666667, -3.77777778, -4.88888889, -6.        ])

# %%
fig, ax = plt.subplots()

ax.plot(X, Y1)
ax.plot(X, Y2)

ax.grid(True)

fig.show()
# Out:
# /tmp/ipykernel_9225/3587034662.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
