# %%
from sympy import *

# %%
x = symbols("x")

# %%
f = 3*x**4 - 12*x**2
f
# Out:
# 3*x**4 - 12*x**2

# %%
plot(f, (x,-5, 5),ylim = (-20,20))

# %%
f = x**4 -4*x**3-13*x**2+28*x+60
f
# Out:
# x**4 - 4*x**3 - 13*x**2 + 28*x + 60

# %%
plot(f, (x,-5,5), ylim = (-40,80))

# %%
f = -x**2 + 2
f
# Out:
# 2 - x**2

# %%
plot(f)

# %%
plot((x**2+6*x-3),(-x**2+6*x-3))

# %%
f = x*(x+2)*(x-3)
f
# Out:
# x*(x - 3)*(x + 2)

# %%
plot(f,6*x,r1,r2, (x,-3,4))

# %%
f.subs(x,-3)
# Out:
# -18

# %%
f.subs(x,4)
# Out:
# 24

# %%
(24+18)/(4+3)
# Out:
# 6.0

# %%
df = diff(f,x)
df
# Out:
# x*(x - 3) + x*(x + 2) + (x - 3)*(x + 2)

# %%
solucao = solve(Eq(df,6), x)
solucao
# Out:
# [1/3 - sqrt(37)/3, 1/3 + sqrt(37)/3]

# %%
N(solucao[0])
# Out:
# -1.69425417676607

# %%
N(solucao[1])
# Out:
# 2.36092084343274

# %%
r1 = 6*(x-solucao[0]) + f.subs(x, solucao[0])
r1
# Out:
# 6*x - 2 + (-8/3 - sqrt(37)/3)*(1/3 - sqrt(37)/3)*(7/3 - sqrt(37)/3) + 2*sqrt(37)

# %%
r2 = 6*(x-solucao[1]) + f.subs(x, solucao[1])
r2
# Out:
# 6*x - 2*sqrt(37) + (-8/3 + sqrt(37)/3)*(1/3 + sqrt(37)/3)*(sqrt(37)/3 + 7/3) - 2

# %%
f = x**2 - x + 5
f
# Out:
# x**2 - x + 5

# %%
plot(f,(x,-2,3))

# %%
f = Piecewise((2*x**2-4,x<=1),(-x-1, True))
f
# Out:
# Piecewise((2*x**2 - 4, x <= 1), (-x - 1, True))

# %%
plot(f, (x,-1,3))

# %%
f = x**3-7*x+6
f
# Out:
# x**3 - 7*x + 6

# %%
plot(f,(x,-4,4))

# %%
sqrt(7/3)
# Out:
# 1.52752523165195

# %%
f = -4*x**3 +3*x**2 + 18*x
f
# Out:
# -4*x**3 + 3*x**2 + 18*x

# %%
df = diff(f,x)
df
# Out:
# -12*x**2 + 6*x + 18

# %%
solve(Eq(df,0), x)
# Out:
# [-1, 3/2]

# %%
plot(f, (x,-2,3))

# %%
f = (x-1)**3
f
# Out:
# (x - 1)**3

# %%
plot(f, (x,-1,3))

# %%
f = x**4 - x**2
f
# Out:
# x**4 - x**2

# %%
plot(f, (x,-1,1))

# %%
f = x**4/4 - 2*x**3 - x**2/2 + 30*x + 10
f
# Out:
# x**4/4 - 2*x**3 - x**2/2 + 30*x + 10

# %%
plot(f, (x,-5,8))

# %%
df = diff(f, x)
df
# Out:
# x**3 - 6*x**2 - x + 30

# %%
dff = diff(df,x)
dff
# Out:
# 3*x**2 - 12*x - 1

# %%
solucao = solve(Eq(dff,0), x)
solucao
# Out:
# [2 - sqrt(39)/3, 2 + sqrt(39)/3]

# %%
dfff = diff(dff, x)
dfff
# Out:
# 6*x - 12

# %%
dfff.subs(x,solucao[0])
# Out:
# -2*sqrt(39)

# %%
N(solucao[0])
# Out:
# -0.0816659994661327

# %%
plot(f, (x,-1,1))
