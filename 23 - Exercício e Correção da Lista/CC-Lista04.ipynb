# %% [markdown]
# # LISTA 04

# %%
from sympy import *

# %%
x = symbols('x')
l = symbols('l')

# %% [markdown]
# # 1° QUESTÃO

# %% [markdown]
# <font size = 5>
#
# Dada a função abaixo.  Mostrar que 𝒇 satisfaz as condições do Teorema de Rolle no intervalo [-3, 3] e determinar os valores de 𝒄 em (-3,3) que satisfaçam 𝒇'(𝒄) = 𝟎.
#
# $$
# f(x) = -x^4 + 8x^2 + 9
# $$
#
# </font>

# %%
f = -x**4 +8*x**2 + 9
f
# Out:
# -x**4 + 8*x**2 + 9

# %%
print(f"Valor de f(-3) = {f.subs(x, -3)}")
print(f"Valor de f(3) = {f.subs(x, 3)}")
# Out:
# Valor de f(-3) = 0
# Valor de f(3) = 0

# %% [markdown]
# <font size = 5>
#
# Valor de _a_ e _b_ são iguais, logo pelo teorema de Roller a derivada deve ser igual a 0 em pelo menos um ponto.
#
# </font>

# %%
df = f.diff(x)
df
# Out:
# -4*x**3 + 16*x

# %%
pontos = solve(Eq(df, 0), x)
for i in pontos:
    print(f"Raiz = {i}")
# Out:
# Raiz = -2
# Raiz = 0
# Raiz = 2

# %%
plot(df, (x, -3, 3), title = "Plot Derivada")

# %%
# reta horizontal em x = -2, 0 e 2
plot(f, (x, -3, 3), title = "Plot Função")

# %% [markdown]
# _______

# %% [markdown]
# # 2° QUESTÃO

# %% [markdown]
# <font size = 5>
#
# Das funções abaixo, escolher a alternativa que contenha os pontos críticos.
#
# </font>

# %% [markdown]
# # 2° QUESTÃO - A
#
# <font size = 5>
#
# $$
# y = x^2 - 3x + 8
# $$
#
# </font>

# %%
f = x**2 -3*x + 8
f
# Out:
# x**2 - 3*x + 8

# %%
df = f.diff(x)
df
# Out:
# 2*x - 3

# %%
# pontos críticos, derivada = 0 ou não existe
solve(Eq(df, 0), x)
# Out:
# [3/2]

# %%
plot(df, (x, 0, 2))

# %%
plot(f, (x, 0, 2))

# %% [markdown]
# # 2° QUESTÃO - B
#
# <font size = 5>
#
# $$
# y = (x^2 - 9)^{2/3}
# $$
#
# </font>

# %%
f = root((x**2-9)**2, 3)
f
# Out:
# ((x**2 - 9)**2)**(1/3)

# %%
df = f.diff(x)
df
# Out:
# 4*x*((x**2 - 9)**2)**(1/3)/(3*(x**2 - 9))

# %%
solve(Eq(df, 0), x)
# Out:
# [0]

# %%
plot(df, (x, -4, 4))

# %%
plot(f, (x, -4, 4))

# %% [markdown]
# # 2° QUESTÃO - C
#
# <font size = 5>
#
# $$
# y = 3-x^3
# $$
#
# </font>

# %%
f = 3 - x**3
f
# Out:
# 3 - x**3

# %%
df = f.diff(x)
df
# Out:
# -3*x**2

# %%
solve(Eq(df, 0), x)
# Out:
# [0]

# %%
plot(df, (x, -2, 2))

# %%
plot(f, (x, -2, 2))

# %% [markdown]
# ___________

# %% [markdown]
# # 3° QUESTÃO
#
# <font size = 5>
#
# Um fio de comprimento 𝒍 é cortado em dois pedaços. Com um deles se fará um círculo e com o outro, um quadrado.
#
# </font>

# %% [markdown]
# <font size = 5>
#
# Desenvolva um código em python que calcule como deve ser cortado o fio a fim de que a soma das duas áreas compreendidas pelas figuras seja 𝒎𝒊́𝒏𝒊𝒎𝒂.
#
# </font>

# %%
f = (x**2)/16 + ((l-x)**2)/(4*pi)
f
# Out:
# x**2/16 + (l - x)**2/(4*pi)

# %%
df = f.diff(x)
df
# Out:
# x/8 + (-2*l + 2*x)/(4*pi)

# %%
# pontos críticos
solve(Eq(df, 0), x)
# Out:
# [4*l/(pi + 4)]

# %%
df2 = df.diff(x)
df2
# valor positivo não importar o valor de x
# logo é mínimo
# Out:
# 1/8 + 1/(2*pi)

# %%
# menor valor para o perimetro do quadrado ('x')
4*l/(pi + 4)
# Out:
# 4*l/(pi + 4)

# %%
# menor valor para o perimetro da circunferência
simplify(l-4*l/(pi + 4))
# Out:
# pi*l/(pi + 4)

# %% [markdown]
# ________________
