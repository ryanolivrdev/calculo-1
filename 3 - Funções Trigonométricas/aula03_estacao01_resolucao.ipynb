# %% [markdown]
# # ESTAÇÃO 01
# ## FUNÇÕES TRIGONOMÉTRICAS
#
# Nessa estação a equipe ficará responsável em fazer uma pesquisa sobre funções trigonométricas. Para isso você precisará baixar o arquivo notebook e importa-lo para o Colab para que no final da atividade seja compartilhado com o professor.

# %% [markdown]
# ____________________________

# %%
from sympy import *

# %%
x = symbols("x")

# %% [markdown]
# __________________________

# %% [markdown]
# ### Pergunta 01
# O que é uma função periódica?
#
# Lembre-se de colocar as referências de onde você retirou as informações

# %% [markdown]
# ### Resposta:
# "As funções periódicas são aquelas nas quais os valores da função (f(x) = y) se repetem para determinados valores da variável x, ou seja, para cada período determinado pelos valores de x, iremos obter valores repetidos para a função."
#
# Veja mais sobre "Funções periódicas" em: https://brasilescola.uol.com.br/matematica/funcoes-periodicas.htm

# %% [markdown]
# _______________________

# %% [markdown]
# ### Pergunta 02
# Quais são as funções trigonométricas?
#
# Lembre-se de colocar as referências de onde você retirou as informações.
#
# <details>
#   <summary> Spoiler </summary>
#   São seis funções no total.
# </details>

# %% [markdown]
# ### Resposta:
# Função seno
#
# Função cosseno
#
# Função tangente
#
# Função secante
#
# Função cossecante
#
# Função cotangente

# %% [markdown]
# ________________________

# %% [markdown]
# ### Pergunta 03
# Construir o gráfico da seguinte função trigonométrica e verificar se é periódica
#
# $$
# y = sen(kx);     k = 1, 2, 3
# $$

# %%
plt = plot(sin(x), sin(2*x), sin(3*x), (x, 0, 2*pi), show = False)

plt.legend = true

plt.show()

# %% [markdown]
# ________________________

# %% [markdown]
# ### Pergunta 04
# Construir o gráfico da seguinte função trigonométrica e verificar se é periódica
#
# $$
# y = sen(kx);     k = 1, 1/2, 1/3
# $$

# %%
plt = plot(sin(x), sin(x/2), sin(x/3), (x, 0, 4*pi), show = False)

plt.legend = true

plt.show()

# %% [markdown]
# ________________

# %% [markdown]
# ### Pergunta 05
# O que aconteceu com os períodos das funções quando você multiplicou e quando você dividiu o valor de $x$?

# %% [markdown]
# ### Resposta:
# * __Multiplicar__: Aumentou a frequência da função
# * __Dividir__: Diminuiu a frequência da função

# %% [markdown]
# _____________________________________________

# %% [markdown]
# ### Pergunta 06
# Construir o gráfico da seguinte função trigonométrica e verificar se é periódica
#
# $$
# y = kcos(x);     k = 1, 2, 3
# $$

# %%
plt = plot(cos(x), 2*cos(x), 3*cos(x), (x, 0, 2*pi), show = False)

plt.legend = true

plt.show()

# %% [markdown]
# ____________________________________

# %% [markdown]
# ### Pergunta 07
# Construir o gráfico da seguinte função trigonométrica e verificar se é periódica
#
# $$
# y = kcos(x);     k = 1, 1/2, 1/3
# $$

# %%
plt = plot(cos(x), cos(x)/2, cos(x)/3, (x, 0, 2*pi), show = False)

plt.legend = true

plt.show()

# %% [markdown]
# ____________________________

# %% [markdown]
# ### Pergunta 08
# Construir o gráfico da seguinte função trigonométrica e verificar se é periódica
#
# $$
# y = kcos(x);     k = 1, -1
# $$

# %%
plt = plot(cos(x), -1*cos(x), (x, 0, 2*pi), show = False)

plt.legend = true

plt.show()

# %% [markdown]
# _____________________________

# %% [markdown]
# ### Pergunta 09
# O que aconteceu com as amplitudes das funções quando você multiplicou e quando você dividiu o valor de $cos$?

# %% [markdown]
# ### Resposta:
# * __Multiplicar__: Aumentou a amplitude da função
# * __Dividir__: Diminuiu a amplitude da função
