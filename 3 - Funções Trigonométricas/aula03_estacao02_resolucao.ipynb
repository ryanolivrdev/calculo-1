# %% [markdown]
# # ESTAÇÃO 02
# ## FUNÇÕES TRIGONOMÉTRICAS INVERSAS
#
# Nessa estação a equipe ficará responsável em fazer uma pesquisa sobre funções trigonométricas inversas. Para isso você precisará baixar o arquivo notebook e importa-lo para o Colab para que no final da atividade seja compartilhado com o professor.

# %% [markdown]
# ____________________________

# %%
from sympy import *

# %%
x = symbols('x')

# %% [markdown]
# __________________________

# %% [markdown]
# ### Pergunta 01
# O que é uma função inversa?
#
# Lembre-se de colocar as referências de onde você retirou as informações

# %% [markdown]
# ### Resposta:
# "A função inversa, como o nome já sugere, é a função f(x)-1, que faz exatamente o inverso da função f(x). Para que uma função admita uma inversa, ela precisa ser bijetora, ou seja, injetora e sobrejetora ao mesmo tempo. A lei de formação de uma função inversa faz o contrário do que a função f(x) faz."
#
# Veja mais sobre "Função inversa" em: https://brasilescola.uol.com.br/matematica/funcao-inversa.htm

# %% [markdown]
# _______________________

# %% [markdown]
# ### Pergunta 02
# Quais são as funções trigonométricas inversas?
#
# Lembre-se de colocar as referências de onde você retirou as informações.
#
# <details>
#   <summary> Spoiler </summary>
#   São seis funções no total.
# </details>

# %% [markdown]
# ### Resposta:
# Função arc seno
#
# Função arc cosseno
#
# Função arc tangente
#
# Função arc secante
#
# Função arc cossecante
#
# Função arc cotangente

# %% [markdown]
# ________________________

# %% [markdown]
# ### Pergunta 03
# Construir o gráfico da seguinte função trigonométrica e verificar se é periódica
#
# $$
# y = arc sen(kx);     k = 1, 2, 3
# $$

# %%
plt = plot(asin(x), asin(2*x), asin(3*x), (x, -2*pi, 2*pi), show = False)

plt.legend = true

plt.show()

# %% [markdown]
# ________________________

# %% [markdown]
# ### Pergunta 04
# Construir o gráfico da seguinte função trigonométrica e verificar se é periódica
#
# $$
# y = arcsen(kx);     k = 1, 1/2, 1/3
# $$

# %%
plt = plot(asin(x), asin(x/2), asin(x/3), (x, -2*pi, 2*pi), show = False)

plt.legend = true

plt.show()

# %% [markdown]
# ________________

# %% [markdown]
# ### Pergunta 05
# O que aconteceu com as funções quando você multiplicou e quando você dividiu o valor de $x$?

# %% [markdown]
# ### Resposta:
# * __Multiplicar__: Diminuiu o dominio da função
# * __Dividir__: Aumentou o dominio da função

# %% [markdown]
# _____________________________________________

# %% [markdown]
# ### Pergunta 06
# Construir o gráfico da seguinte função trigonométrica e verificar se é periódica
#
# $$
# y = k * arccos(x);     k = 1, 2, 3
# $$

# %%
plt = plot(acos(x), 2*acos(x), 3*acos(x), (x, -2*pi, 2*pi), show = False)

plt.legend = true

plt.show()

# %% [markdown]
# ____________________________________

# %% [markdown]
# ### Pergunta 07
# Construir o gráfico da seguinte função trigonométrica e verificar se é periódica
#
# $$
# y = k*arccos(x);     k = 1, 1/2, 1/3
# $$

# %%
plt = plot(acos(x), acos(x)/2, acos(x)/3, (x, -2*pi, 2*pi), show = False)

plt.legend = true

plt.show()

# %% [markdown]
# ____________________________

# %% [markdown]
# ### Pergunta 08
# Construir o gráfico da seguinte função trigonométrica e verificar se é periódica
#
# $$
# y = k*arccos(x);     k = 1, -1
# $$

# %%
plt = plot(acos(x), -1*acos(x), (x, -2*pi, 2*pi), show = False)

plt.legend = true

plt.show()

# %% [markdown]
# _____________________________

# %% [markdown]
# ### Pergunta 09
# O que aconteceu com as funções quando você multiplicou e quando você dividiu o valor de $arccos$?

# %% [markdown]
# ### Resposta:
# * __Multiplicar__: Aumentou a amplitude da função
# * __Dividir__: Diminuiu a amplitude da função
